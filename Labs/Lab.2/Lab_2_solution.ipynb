# %% [markdown]
# # Lab 2 — Tic‑Tac‑Toe (n×n)
#
# In this lab you will build an **n×n tic‑tac‑toe** game.
#
# As you work through the exercises, make sure your solutions work for **any** board size `n` (not just 3×3), unless an exercise states otherwise.

# %% [markdown]
# ## Responsible Use of Large Language Models (LLMs)
#
# In this lab, **you are allowed and encouraged to use LLMs responsibly** as learning tools.
# Think of them as **tutors, reference books, and debugging partners** — not as answer generators.
#
# ### Appropriate uses
# - Asking for **explanations** of Python concepts (lists, loops, functions, conditionals)
# - Getting **hints** or alternative approaches when you are stuck
# - Debugging errors *after* you try to reason about them yourself
# - Asking an LLM to **explain your own code** back to you
#
# ### Not appropriate
# - Copy‑pasting complete solutions without understanding them
# - Submitting code you cannot explain
# - Using an LLM instead of thinking through the problem first
#
# You may be asked to explain your code or reflect briefly on how you used an LLM.
#
# ### Commonly used LLMs (examples)
#
# - **ChatGPT** — https://chat.openai.com
#   General‑purpose reasoning, explanations, and debugging. Good for step‑by‑step thinking.
#
# - **Claude** — https://claude.ai
#   Strong at reading longer code and giving structured explanations.
#
# - **Gemini** — https://gemini.google.com
#   Useful for conceptual explanations and comparisons.
#
# - **GitHub Copilot** — https://github.com/features/copilot
#   IDE‑integrated suggestions. Treat suggestions as *ideas*, not answers.
#
# - **Perplexity** — https://www.perplexity.ai
#   Search‑oriented answers with sources; useful for “how does X work?” questions.
#
# No single tool is required or preferred. What matters is **how** you use it.

# %% [markdown]
# ## Use of Large Language Models
#
# We are explicitly going to use LLMs to help with this Lab. Choose an LLM that you will use today. Unless you are already paying for a service, please just use the free versions.
#
# In exercise 1, we'll practice using an LLM. For subsequent exercises, the rule is that you first try to solve it yourself. If you can't do it off the top of you head, go through the lectures. Everything you need to know is there, including very useful examples. In some cases, solutions are simply minimal modifications of code from lecture. Test your solution and demonstrate that it works as explect. If a problem's solution is eluding you, practice solving problems in the same way as in class, make a plan and decompose it into smaller parts before coding. If it doesn't work correctly, iterate until it does or you are stuck.
#
# **You may use LLMs if you get stuck.** If you do so, you will need to add cells to this notebook showing:
#   * Your original solution until you got stuck.
#   * The final prompt you used to solve the problem.
#   * The solution and an explanation of what was your mistake, lack of understanding, or misunderstanding.

# %% [markdown]
# *Exercise 1:* Write a function that creates an **n×n matrix** (a list of lists) representing the state of a tic‑tac‑toe game.
#
# Use the integers:
#
# - `0` = empty
# - `1` = `"X"`
# - `2` = `"O"`

# %% [markdown]
# **note: for all work, copilot in-line suggestions were used for general help but lectures were the biggest reference**

# %%
# Write your solution here

# declare variables for players and empty spaces
player_1 = "X"
player_2 = "O"
empty = " "

# board size variable
size = 3

# function to return the board size
def board_size():
    return size

def make_board(size=size):
    # create list of lists to represent the board with empty spaces.
    board=[[empty]*size for i in range(size)]
    return board

def display_board(board):
    for row in board:
        print(" | ".join(row))
        print("-" * (size * 4 - 3))

# %%
# Test your solution here

display_board(make_board())
# Out:
#   |   |
# ---------
#   |   |
# ---------
#   |   |
# ---------

# %%
# Ask an LLM for 3 different solutions here

# renamed functions in this section to prevent breaking exercises 5-13.
# using gemini flash
# prompt: provide 3 different python code solutions compared to provided code to generate a tictactoe board

# SOLUTION 1: 1D Flat List with Numeric Mapping
def make_board_llm_1():
    return [" "] * 9

def display_board_llm_1(board):
    for i in range(0, 9, 3):
        print(f" {board[i]} | {board[i+1]} | {board[i+2]} ")
        if i < 6:
            print("---+---+---")

# Example
b1 = make_board_llm_1()
b1[4] = "X"
print("!!!BOARD 1!!!")
display_board_llm_1(b1)

# SOLUTION 2: Object-Oriented Class Encapsulation
class TicTacToeBoard:
    def __init__(self, size: int = 3):
        self.size = size
        self.grid = [[" " for _ in range(size)] for _ in range(size)]

    def __str__(self):
        divider = "\n" + "-" * (self.size * 4 - 1) + "\n"
        rows = [" " + " | ".join(row) + " " for row in self.grid]
        return divider.join(rows)

# Example
board_2 = TicTacToeBoard(size=3)
board_2.grid[1][1] = "O"
print("\n!!!BOARD 2!!!")
print(board_2)

# SOLUTION 3: Dictionary / Hash Map (Coordinate-Keyed Sparse Board)
def make_board_llm_3(size: int = 3) -> dict:
    return {(r, c): " " for r in range(size) for c in range(size)}

def display_board_llm_3(board: dict, size: int = 3):
    rows = []
    for r in range(size):
        row_str = " | ".join(board[(r, c)] for c in range(size))
        rows.append(row_str)
    divider = "\n" + "-" * (size * 4 - 3) + "\n"
    print(divider.join(rows))

# Example
board_3 = make_board_llm_3(3)
board_3[(0, 0)] = "X"
print("\n!!!BOARD 3!!!")
display_board_llm_3(board_3, 3)


# Then compare them to your own.

# %% [markdown]
# **Question:** Which solution most closely matches your solution? What are the main differences?
#
# **Answer:** Solution 2 is closest to my solution. Both build a matrix of independent rows using lists. The main difference is that Solution 2 encapsulates the grid inside a class.

# %% [markdown]
# *Exercise 2:* Write a function that takes two integers `n` and `m` and **draws** an `n` by `m` game board.
#
# For example, the following is a 3×3 board:
#
# ```
#    --- --- ---
#   |   |   |   |
#    --- --- ---
#   |   |   |   |
#    --- --- ---
#   |   |   |   |
#    --- --- ---
# ```

# %%
# Write your solution here
# no LLM used here

def display_board(n, m):
    for i in range(n):
        row = ["   "] * m
        print("|".join(row))
        if i < n - 1:
            print("-" * (m * 4 - 1))

# %%
# Test your solution here
display_board(3, 3)

# %% [markdown]
# *Exercise 3:* Modify Exercise 2 so that it takes a matrix in the format from Exercise 1 and draws a tic‑tac‑toe board with `"X"`s and `"O"`s.

# %%
# Write your solution here
# no LLM used here

space_character = {empty: " ", player_1: "X", player_2: "O"}

def draw_board(board):
    n = len(board)
    m = len(board[0])
    for i in range(n):
        # convert internal integers (0, 1, 2) to display characters (" ", "X", "O")
        row_chars = [f" {space_character[cell]} " for cell in board[i]]
        print("|".join(row_chars))
        if i < n - 1:
            print("-" * (m * 4 - 1))

# %%
# Test your solution here

b = make_board(3)
b[1][1] = player_1
draw_board(b)

# %% [markdown]
# *Exercise 4:* Write a function that takes an `n×n` matrix representing a tic‑tac‑toe game and returns one of the following values:
#
# - `-1` if the game is **incomplete** (still empty spaces and no winner)
# - `0` if the game is a **draw**
# - `1` if **player 1** (`"X"`) has won
# - `2` if **player 2** (`"O"`) has won
#
# Here are some example inputs you can use to test your code:

# %% [markdown]
# prompt: this function (get_winner) is returning 0 (for draw) when it it is supposed to return -1 (for incomplement) on boards that have empty spaces. why? how do i fix it?
#
# mistake: i misunderstood in exercise 1 and set empty as a string (" ") and it did not cause an issue for me until now. the test matrixes provided need 0 not a string because of this, "if empty in board[r]" alwys lead to false whihc is a draw

# %%
# Write your solution here
# gemini assisted here.

empty = 0 # fix for empty not being actual integer 0, from llm (only llm change)

def get_winner(board):
    n = len(board)

    # check rows
    for r in range(n):
        if len(set(board[r])) == 1 and board[r][0] != empty:
            return board[r][0]

    # check columns
    for c in range(n):
        col_vals = [board[r][c] for r in range(n)]
        if len(set(col_vals)) == 1 and col_vals[0] != empty:
            return col_vals[0]

    # check primary diagonal
    diag1 = [board[i][i] for i in range(n)]
    if len(set(diag1)) == 1 and diag1[0] != empty:
        return diag1[0]

    # check secondary diagonal
    diag2 = [board[i][n - 1 - i] for i in range(n)]
    if len(set(diag2)) == 1 and diag2[0] != empty:
        return diag2[0]

    # check for empty spaces (incomplete game)
    for r in range(n):
        if empty in board[r]:
            return -1

    # if no empty space no winner, it's a draw
    return 0

# %%
# Test your solution here

winner_is_2 = [[2, 2, 0],
	[2, 1, 0],
	[2, 1, 1]]

winner_is_1 = [[1, 2, 0],
	[2, 1, 0],
	[2, 1, 1]]

winner_is_also_1 = [[0, 1, 0],
	[2, 1, 0],
	[2, 1, 1]]

no_winner = [[1, 2, 0],
	[2, 1, 0],
	[2, 1, 2]]

also_no_winner = [[1, 2, 0],
	[2, 1, 0],
	[2, 1, 0]]

# test all
print("Expected: 2  | Actual:", get_winner(winner_is_2))
print("Expected: 1  | Actual:", get_winner(winner_is_1))
print("Expected: 1  | Actual:", get_winner(winner_is_also_1))
print("Expected: -1 | Actual:", get_winner(no_winner))
print("Expected: -1 | Actual:", get_winner(also_no_winner))
# Out:
# Expected: 2  | Actual: 2
# Expected: 1  | Actual: 1
# Expected: 1  | Actual: 1
# Expected: -1 | Actual: -1
# Expected: -1 | Actual: -1

# %% [markdown]
# *Exercise 5:* Write a function that takes a game board, a player number, and `(row, col)` coordinates and places the correct mark (`"X"` or `"O"`) in that location.
#
# Requirements:
#
# - Only allow placing a mark in a previously empty location.
# - Return `True` if the move was successful, and `False` otherwise.

# %%
# Write your solution here

def place_mark(board, player, location):
    r, c = location
    n = len(board)
    m = len(board[0])

    # check boundaries
    if r < 0 or r >= n or c < 0 or c >= m:
        return False

    # check if empty
    if board[r][c] == empty:
        board[r][c] = player
        return True

    return False

# %%
# Test your solution here
# solutions broke from here onward because of the "3 LLM solutions" section. oops. did not run that before all of these. error fixed by renaming functions.

b = make_board(3)
success = place_mark(b, player_1, (0, 0))
print("Move successful:", success)
print("Space taken:", place_mark(b, player_2, (0, 0)))

# %% [markdown]
# *Exercise 6:* Modify Exercise 3 to show **row and column labels** so that players can specify locations like `"A2"` or `"C1"`.

# %%
# Write your solution here

def draw_labeled_board(board):
    n = len(board)
    m = len(board[0])

    # print column headers
    col_headers = [str(i+1) for i in range(m)]
    print("    " + "   ".join(col_headers))

    # print rows with letter headers
    for i in range(n):
        row_chars = [f" {space_character[cell]} " for cell in board[i]]
        print(f"{row_names[i]}  " + "|".join(row_chars))
        if i < n - 1:
            print("   " + "-" * (m * 4 - 1))

# %%
# Test your solution here

b = make_board(3)
b[1][1] = player_1
draw_labeled_board(b)

# %% [markdown]
# *Exercise 7:* Write a function that takes a board, a player number, and a location string (as in Exercise 6), then uses your function from Exercise 5 to update the board.

# %%
# Write your solution here

row_names = list("ABCDEFGHIJKLMNOPQRSTUVWXYZ")

def parse_location(loc_str, n, m):
    if len(loc_str) < 2:
        return None

    r_char = loc_str[0].upper()
    c_str = loc_str[1:]

    if r_char not in row_names:
        return None
    r = row_names.index(r_char)

    if not c_str.isdigit():
        return None
    c = int(c_str) - 1

    if r >= n or c < 0 or c >= m:
        return None

    return (r, c)

def apply_labeled_move(board, player, loc_str):
    n = len(board)
    m = len(board[0])
    loc = parse_location(loc_str, n, m)
    if loc is None:
        return False
    return place_mark(board, player, loc)

# %%
# Test your solution here

b = make_board(3)
apply_labeled_move(b, player_2, "B2")
draw_labeled_board(b)

# %% [markdown]
# *Exercise 8:* Write a function that is called with a board and player number, takes input from the player using Python's `input()`, and modifies the board using your function from Exercise 7.
#
# Keep asking for input until the player enters a valid location that results in a valid move.

# %% [markdown]
# prompt: when giving correct expected input to while loop the loop does not end and loops forever
# issue: function was called but not assigned the true/false value given. so valid_move stayed false so the loop never broke
#
# ORIGINAL CODE
# def take_move(board, player):
#     valid_move = False
#     while not valid_move:
#         loc_str = input("Enter move: ")
#         apply_labeled_move(board, player, loc_str)
#         if not valid_move:
#                print("Invalid move. Try again.")

# %%
# Write your solution here
# had to use gemini to fix an issue here

def take_move(board, player):
    valid_move = False
    while not valid_move:
        loc_str = input(f"Player {space_character[player]}, input location (e.g B2): ")
        valid_move = apply_labeled_move(board, player, loc_str)
        if not valid_move:
            print("Invalid move. Try again.")

# %%
# Test your solution here

b = make_board(3)
take_move(b, player_1)
draw_labeled_board(b)

# %% [markdown]
# *Exercise 9:* Use all of the previous exercises to implement a full tic‑tac‑toe game:
#
# - draw the board,
# - repeatedly ask two players for a location,
# - apply valid moves,
# - check the game status until a player wins or the game is a draw.

# %%
# Write your solution here

def play_tic_tac_toe(size):
    print(f"Welcome to {size}x{size} Tic-Tac-Toe")
    print("-------------------------")
    board = make_board(size)
    current_player = player_1

    while True:
        draw_labeled_board(board)
        take_move(board, current_player)

        status = get_winner(board)
        if status != -1:
            draw_labeled_board(board)
            if status == 0:
                print("Game is a draw!")
            else:
                print(f"Player {space_character[status]} wins!")
            break

        if current_player == player_1:
            current_player = player_2
        else:
            current_player = player_1

# %%
# Test your solution here

play_tic_tac_toe(3)

# %% [markdown]
# *Exercise 10:* Test that your game works for **5×5** tic‑tac‑toe.

# %% [markdown]
# prompt to gemini flash: get_winner function works on 3x3 but gives error on 5x5
#
# mistake: hardcoded range(3) by mistake in win check loops. soluton given was "n = len(board)"

# %%
# Test your solution here

play_tic_tac_toe(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 3
#       1 # Test your solution here
#       2
# ----> 3 play_tic_tac_toe(5)
#
# NameError: name 'play_tic_tac_toe' is not defined

# %% [markdown]
# *Exercise 11:* Develop a version of the game where one player is the computer.
#
# Note: you do **not** need an extensive search for the best move. For example, you can have the computer:
# - block obvious losses
# - otherwise try to create a winning row/column/diagonal

# %%
# Write your solution here

import copy

def get_valid_moves(board):
    moves = []
    n = len(board)
    for r in range(n):
        for c in range(n):
            if board[r][c] == empty:
                moves.append((r, c))
    return moves

def heuristic_ai_move(board, player):
    if player == player_1:
        opponent = player_2
    else:
        opponent = player_1

    valid_moves = get_valid_moves(board)

    # try to find a winning move
    for move in valid_moves:
        test_board = copy.deepcopy(board)
        place_mark(test_board, player, move)
        if get_winner(test_board) == player:
            return move

    # try to block opponent's winning move
    for move in valid_moves:
        test_board = copy.deepcopy(board)
        place_mark(test_board, opponent, move)
        if get_winner(test_board) == opponent:
            return move

    # pick the first available open space
    if valid_moves:
        return valid_moves[0]
    return None

# %%
# Test your solution here

b = make_board(3)
b[0][0] = player_1
b[0][1] = player_1

# AI as player 2 should block at 0, 2
move = heuristic_ai_move(b, player_2)
print("AI blocked at:", move)

# %% [markdown]
# *Exercise 12:* Develop a version of the game where one player is the computer. This time, write a computer player using exhaustive search with a max depth parameter, similar to lecture.

# %%
# Write your solution here

def score_board(board, maximizing_player):
    winner = get_winner(board)
    if winner == maximizing_player:
        return 10
    elif winner != 0 and winner != -1:
        return -10
    return 0

def exhaustive_search(board, current_player, maximizing_player, depth):
    status = get_winner(board)

    # stop if game over or depth limit reached
    if status != -1 or depth == 0:
        return score_board(board, maximizing_player)

    moves = get_valid_moves(board)

    # evaluate children
    if current_player == maximizing_player:
        best_score = -float('inf')
        for move in moves:
            next_board = copy.deepcopy(board)
            place_mark(next_board, current_player, move)
            next_player = player_2 if current_player == player_1 else player_1
            score = exhaustive_search(next_board, next_player, maximizing_player, depth - 1)
            if score > best_score:
                best_score = score
        return best_score
    else:
        best_score = float('inf')
        for move in moves:
            next_board = copy.deepcopy(board)
            place_mark(next_board, current_player, move)
            next_player = player_2 if current_player == player_1 else player_1
            score = exhaustive_search(next_board, next_player, maximizing_player, depth - 1)
            if score < best_score:
                best_score = score
        return best_score

def exhaustive_ai_move(board, player, depth):
    best_score = -float('inf')
    best_move = None
    moves = get_valid_moves(board)

    for move in moves:
        test_board = copy.deepcopy(board)
        place_mark(test_board, player, move)
        next_player = player_2 if player == player_1 else player_1
        score = exhaustive_search(test_board, next_player, player, depth - 1)

        if score > best_score:
            best_score = score
            best_move = move

    return best_move if best_move else moves[0]

# %%
# Test your solution here

b = make_board(3)
move = exhaustive_ai_move(b, player_1, 2)
print("Exhaustive AI initial move:", move)

# %% [markdown]
# *Exercise 13:* Make the 2 computer players play each-other for 10 games on a 3x3, then 4x4, then 5x5 grid. Set the max depth so that the games only take seconds. Measure the "smarter" player's win rate for each grid.

# %%
# Write your solution here

def ai_vs_ai_series(size, num_games, depth_p1, depth_p2):
    p1_wins = 0
    p2_wins = 0
    draws = 0

    for _ in range(num_games):
        board = make_board(size)
        current_player = player_1

        while True:
            if current_player == player_1:
                move = exhaustive_ai_move(board, current_player, depth_p1)
            else:
                move = heuristic_ai_move(board, current_player)

            place_mark(board, current_player, move)
            status = get_winner(board)

            if status != -1:
                if status == player_1:
                    p1_wins += 1
                elif status == player_2:
                    p2_wins += 1
                else:
                    draws += 1
                break

            current_player = player_2 if current_player == player_1 else player_1

    print(f"Board: {size}x{size} | Depth P1: {depth_p1} | Games: {num_games}")
    print(f"P1 (Exhaustive) Wins: {p1_wins} | P2 (Heuristic) Wins: {p2_wins} | Draws: {draws}")

# %%
# Test your solution here

ai_vs_ai_series(3, 10, 3, 2)
ai_vs_ai_series(4, 10, 2, 2)
ai_vs_ai_series(5, 10, 2, 2)

# %% [markdown]
# ## Lab Summary
#
# In this lab you practiced:
#
# - Representing a game board using nested lists
# - Writing small, focused functions
# - Using conditionals and loops to analyze program state
# - Thinking carefully about assumptions and edge cases
# - Using LLMs **responsibly** as learning tools rather than answer generators
#
# The goal is not just to make the program work, but to understand *why* it works.
# That understanding is what allows you to use tools — including AI — effectively.
